# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#Installing Necessary Python Libraries Java Toolkits
# %cd "/content/gdrive/My Drive/DrQA"
# !pip install -r requirements.txt; 
# !sudo apt-get remove openjdk*
import os       #importing os to set environment variable
def install_java():
  # !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null      #install openjdk
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"     #set environment variable
install_java()
# Out:
# /content/gdrive/My Drive/DrQA
# ...
#      |████████████████████████████████| 102kB 4.1MB/s
# ...
#      |████████████████████████████████| 61kB 5.7MB/s
# ...
#      |████████████████████████████████| 92kB 7.5MB/s
# ...
#      |████████████████████████████████| 51kB 5.9MB/s
# ...
#   Found existing installation: pexpect 4.8.0
#     Uninstalling pexpect-4.8.0:
#       Successfully uninstalled pexpect-4.8.0
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'openjdk-9-jre-headless' for glob 'openjdk*'
# Note, selecting 'openjdk-8-jdk' for glob 'openjdk*'
# Note, selecting 'openjdk-8-jre' for glob 'openjdk*'
# Note, selecting 'openjdk-6-jre' for glob 'openjdk*'
# Note, selecting 'openjdk-6-jre-headless' for glob 'openjdk*'
# Note, selecting 'openjdk-11-demo' for glob 'openjdk*'
# Note, selecting 'openjdk-8-demo' for glob 'openjdk*'
# Note, selecting 'openjdk-11-source' for glob 'openjdk*'
# Note, selecting 'openjdk-8-jre-dcevm' for glob 'openjdk*'
# ...

# %%
import os   

os.environ["PYTHONPATH"] += ":/content/gdrive/My Drive/DrQA"
os.environ["PYTHONPATH"] += ":/content/gdrive/My Drive/BiDAF/question-answering"
# %env GOOGLE_APPLICATION_CREDENTIALS=/content/gdrive/My Drive/DrQA/thinquad-c461ef369c34.json
# %env CLASSPATH=/content/gdrive/My Drive/corenlp/*
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/content/gdrive/My Drive/DrQA/thinquad-c461ef369c34.json
# env: CLASSPATH=/content/gdrive/My Drive/corenlp/*

# %%
#Working of the BIDAF Reader
# %cd "/content/gdrive/My Drive/BiDAF/question-answering"
# !python interactive.py --checkpoint checkpoints/bidaf/checkpoint_best.pt
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Drb48yf2_bMaFdZlpmvVXjCrCMX4Szqz/question-answering
# [2020-05-27 08:40:41] COMMAND: interactive.py --checkpoint checkpoints/bidaf/checkpoint_best.pt
# [2020-05-27 08:40:42] Arguments: {'seed': 42, 'data': 'data', 'max_tokens': 16000, 'batch_size': 32, 'num_workers': 4, 'arch': 'bidaf', 'max_epoch': 50, 'clip_norm': 10, 'lr': 0.01, 'momentum': 0.99, 'weight_decay': 0.0, 'lr_shrink': 0.1, 'min_lr': 1e-06, 'log_file': 'logs/bidaf.log', 'checkpoint_dir': 'checkpoints/bidaf', 'restore_file': 'checkpoint_last.pt', 'save_interval': 1, 'no_save': False, 'epoch_checkpoints': False, 'embed_path': None, 'embed_dim': 300, 'hidden_size': 128, 'context_layers': 1, 'question_layers': 1, 'dropout': 0.2, 'bidirectional': 'True', 'tune_embed': 1000, 'num_features': 0, 'checkpoint': 'checkpoints/bidaf/checkpoint_best.pt', 'tokenizer': 'corenlp'}
# [2020-05-27 08:40:42] Loaded a dictionary with 93685 words
# ...

# %%
#Record Audio
# %cd /content/gdrive/My Drive/BiDAF/question-answering
from mic_recorder import get_audio
import speech
audio, sr = get_audio()
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Drb48yf2_bMaFdZlpmvVXjCrCMX4Szqz/question-answering
# <script>
# var my_div = document.createElement("DIV");
# var my_p = document.createElement("P");
# var my_btn = document.createElement("BUTTON");
# var t = document.createTextNode("Press to start recording");
#
# my_btn.appendChild(t);
# //my_p.appendChild(my_btn);
# my_div.appendChild(my_btn);
# document.body.appendChild(my_div);
#
# var base64data = 0;
# var reader;
# var recorder, gumStream;
# var recordButton = my_btn;
#
# var handleSuccess = function(stream) {
#   gumStream = stream;
#   var options = {
#     //bitsPerSecond: 8000, //chrome seems to ignore, always 48k
#     mimeType : 'audio/webm;codecs=opus'
#     //mimeType : 'audio/webm;codecs=pcm'
#   };
#   //recorder = new MediaRecorder(stream, options);
#   recorder = new MediaRecorder(stream);
#   recorder.ondataavailable = function(e) {
#     var url = URL.createObjectURL(e.data);
# ...

# %%
#Convert to Text
import scipy
scipy.io.wavfile.write('recording.wav', sr, audio)
text = speech.sample_recognize('recording.wav')
text = text + "?"
print(text)
# Out:
# Transcript: who is the prime minister of Japan
# who is the prime minister of Japan?

# %%
#Play Audio
from IPython.display import Audio
# sound_file = 'recording.wav'
# Audio(sound_file, autoplay=True)

# %%
# %cd "/content/gdrive/My Drive/BiDAF/question-answering"
# !python qa2.py  --checkpoint "checkpoints/bidaf/checkpoint_best.pt" --question "{text}"
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Drb48yf2_bMaFdZlpmvVXjCrCMX4Szqz/question-answering
# 05/27/2020 09:13:34 AM: [ CUDA enabled (GPU -1) ]
# 05/27/2020 09:13:34 AM: [ Initializing pipeline... ]
# 05/27/2020 09:13:34 AM: [ Initializing document ranker... ]
# 05/27/2020 09:13:34 AM: [ Loading /content/gdrive/My Drive/DrQA/data/thinquad/thinquad-tfidf-ngram=2-hash=16777216-tokenizer=simple.npz ]
# 05/27/2020 09:13:41 AM: [ Initializing document reader... ]
# 05/27/2020 09:13:41 AM: [ Loading model /content/gdrive/My Drive/DrQA/data/reader/multitask.mdl ]
# 05/27/2020 09:13:51 AM: [ Initializing tokenizers and document retrievers... ]
# 05/27/2020 09:13:53 AM: [ COMMAND: qa2.py --checkpoint checkpoints/bidaf/checkpoint_best.pt --question who is the prime minister of Japan? ]
# ...

# %%
sound_file = 'output.mp3'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
